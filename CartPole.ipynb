# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name, render_mode="human")
# Out:
# /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
#Load environment
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, trunc, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# objc[27180]: Class SDL_RumbleMotor is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00d40) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x1231689c8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDL_RumbleContext is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00d90) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168a18). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDLApplication is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00890) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168a68). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDLAppDelegate is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba008e0) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168ab8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDLTranslatorResponder is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00958) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168b30). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDLMessageBoxPresenter is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00980) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168b58). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDL_cocoametalview is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba009d0) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168ba8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDLOpenGLContext is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00a20) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168bf8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDL_ShapeData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00a98) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168c70). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDL_CocoaClosure is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00ae8) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168cc0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDL_VideoData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00b38) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168d10). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDL_WindowData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00b88) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168d60). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDLWindow is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00bb0) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168d88). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class Cocoa_WindowListener is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00bd8) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168db0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class SDLView is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00c50) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168e28). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class METAL_RenderData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00cc8) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168ea0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[27180]: Class METAL_TextureData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11ba00d18) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x123168ef0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# Episode:1 Score:11.0
# Episode:2 Score:24.0
# Episode:3 Score:22.0
# Episode:4 Score:12.0
# Episode:5 Score:11.0

# %%
#Train RL Model
log_path = os.path.join('Training', 'Logs')

# %%
env = DummyVecEnv([lambda: gym.make(environment_name)])
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 7688 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5187        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007989194 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00167    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.45        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 49.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4769        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010062711 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0878      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4554        |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007307212 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 55.6        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 4314      |
# |    iterations           | 5         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0072598 |
# |    clip_fraction        | 0.0733    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.603    |
# |    explained_variance   | 0.283     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 28.7      |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.0167   |
# |    value_loss           | 62.9      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4282        |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007766337 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 63          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4243        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008108548 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.14        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 33.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4220         |
# |    iterations           | 8            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0055440026 |
# |    clip_fraction        | 0.0592       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.57         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00708     |
# |    value_loss           | 21.6         |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 4212      |
# |    iterations           | 9         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0069113 |
# |    clip_fraction        | 0.0568    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.565    |
# |    explained_variance   | 0.82      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.9       |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -0.00559  |
# |    value_loss           | 26.1      |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4199         |
# |    iterations           | 10           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0043190704 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00323     |
# |    value_loss           | 14.4         |
# ------------------------------------------

# %%
env.close()

# %%
#Save and Reload
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole1')

# %%
model.save(PPO_Path)

# %%
del model

# %%
model.learn(total_timesteps=1000)
# Out:
# Logging to Training/Logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 6338 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
model = PPO.load(PPO_Path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env = gym.make(environment_name, render_mode="human")
# Out:
# /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
#Evaluation
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (np.float64(200.0), np.float64(0.0))

# %%
env.close()

# %%
# %pip install gym
# Out:
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 11.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in ./.venv/lib/python3.13/site-packages (from gym) (2.5.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.venv/lib/python3.13/site-packages (from gym) (3.1.2)
# Collecting gym_notices>=0.0.4 (from gym)
#   Downloading gym_notices-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading gym_notices-0.1.0-py3-none-any.whl (3.3 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827727 sha256=dcdb65853e34bb57d1c582796ba7dd40148d2efe6827e1955995db2f30f24944
#   Stored in directory: /Users/aidantyler/Library/Caches/pip/wheels/1d/34/c6/856a1e1eff47d8f18545c833b6138ae1e9f53c7de9bcc5f31d
# Successfully built gym
# Installing collected packages: gym_notices, gym
# Successfully installed gym-0.26.2 gym_notices-0.1.0
#
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install stable-baselines3[extra]
# Out:
# zsh:1: no matches found: stable-baselines3[extra]
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in ./.venv/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in ./.venv/lib/python3.13/site-packages (from gymnasium) (2.5.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.venv/lib/python3.13/site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.venv/lib/python3.13/site-packages (from gymnasium) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.venv/lib/python3.13/site-packages (from gymnasium) (0.0.6)
#
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
