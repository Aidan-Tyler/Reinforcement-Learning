# %%
# %pip install "gymnasium[box2d]"
# Out:
# Requirement already satisfied: gymnasium[box2d] in ./.venv/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in ./.venv/lib/python3.13/site-packages (from gymnasium[box2d]) (2.5.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.venv/lib/python3.13/site-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.venv/lib/python3.13/site-packages (from gymnasium[box2d]) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.venv/lib/python3.13/site-packages (from gymnasium[box2d]) (0.0.6)
# Collecting box2d==2.3.10 (from gymnasium[box2d])
#   Downloading Box2D-2.3.10-cp313-cp313-macosx_11_0_arm64.whl.metadata (573 bytes)
# Requirement already satisfied: pygame-ce>=2.1.3 in ./.venv/lib/python3.13/site-packages (from gymnasium[box2d]) (2.5.7)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.1-py3-none-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Downloading Box2D-2.3.10-cp313-cp313-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.9 MB/s eta 0:00:00
# Downloading swig-4.4.1-py3-none-macosx_10_9_universal2.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 35.2 MB/s eta 0:00:00
# Installing collected packages: swig, box2d
# Successfully installed box2d-2.3.10 swig-4.4.1
#
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = 'CarRacing-v3'
env = gym.make(environment_name)
# Out:
# objc[59612]: Class SDL_RumbleMotor is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84d40) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3c9c8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDL_RumbleContext is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84d90) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3ca18). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDLApplication is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84890) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3ca68). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDLAppDelegate is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb848e0) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cab8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDLTranslatorResponder is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84958) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cb30). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDLMessageBoxPresenter is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84980) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cb58). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDL_cocoametalview is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb849d0) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cba8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDLOpenGLContext is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84a20) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cbf8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDL_ShapeData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84a98) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cc70). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDL_CocoaClosure is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84ae8) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3ccc0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDL_VideoData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84b38) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cd10). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDL_WindowData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84b88) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cd60). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDLWindow is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84bb0) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cd88). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class Cocoa_WindowListener is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84bd8) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cdb0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class SDLView is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84c50) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3ce28). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class METAL_RenderData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84cc8) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cea0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[59612]: Class METAL_TextureData is implemented in both /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x11bb84d18) and /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x11dd3cef0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.

# %%
#Train model
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training/Logs/PPO_11
# -----------------------------
# | time/              |      |
# |    fps             | 257  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 141          |
# |    iterations           | 2            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0074338736 |
# |    clip_fraction        | 0.0845       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.0151       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.366        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00599     |
# |    std                  | 0.991        |
# |    value_loss           | 0.736        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 3           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009139701 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0712      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00612    |
# |    std                  | 0.987       |
# |    value_loss           | 0.572       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 4           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010269264 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.0646      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00813    |
# |    std                  | 0.975       |
# |    value_loss           | 0.488       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 5           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012171679 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0723      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.971       |
# |    value_loss           | 0.426       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 6           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012255253 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.964       |
# |    value_loss           | 0.32        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 7           |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009292684 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0348      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00916    |
# |    std                  | 0.957       |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 8           |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014828645 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0717      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.952       |
# |    value_loss           | 0.35        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 9           |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011492646 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.948       |
# |    value_loss           | 0.571       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 10          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017828591 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.933       |
# |    value_loss           | 0.537       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 11          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017630257 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0605      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.928       |
# |    value_loss           | 0.254       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 12          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015035238 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0771      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.921       |
# |    value_loss           | 0.452       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 13          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017885534 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0595      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.909       |
# |    value_loss           | 0.361       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 14          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025379527 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0844      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.034      |
# |    std                  | 0.904       |
# |    value_loss           | 0.285       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 15          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025909036 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0108      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0296     |
# |    std                  | 0.893       |
# |    value_loss           | 0.301       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 16          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015738396 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0574      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.886       |
# |    value_loss           | 0.203       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 17          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017321073 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.876       |
# |    value_loss           | 0.138       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 18          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018523112 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0157      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.866       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 19          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.015477624 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0414      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.851       |
# |    value_loss           | 0.384       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 20          |
# |    time_elapsed         | 424         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.024083504 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0279     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0272     |
# |    std                  | 0.836       |
# |    value_loss           | 0.238       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 21          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.025024675 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00835     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.825       |
# |    value_loss           | 0.149       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 22          |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.023951102 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.814       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 23          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.027718514 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0471      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 0.806       |
# |    value_loss           | 0.301       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 24          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.020451184 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.8         |
# |    value_loss           | 0.614       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 25          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.030602781 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0532      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.795       |
# |    value_loss           | 0.582       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 26          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.020889234 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0553      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.788       |
# |    value_loss           | 0.625       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 27          |
# |    time_elapsed         | 573         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.025017703 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.179       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.781       |
# |    value_loss           | 0.903       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 28          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.035187133 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.214       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.777       |
# |    value_loss           | 0.777       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 29         |
# |    time_elapsed         | 614        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02584818 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0638     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0068    |
# |    std                  | 0.772      |
# |    value_loss           | 0.429      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 30          |
# |    time_elapsed         | 637         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.032566346 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.771       |
# |    value_loss           | 0.712       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 31         |
# |    time_elapsed         | 659        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02615702 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.44      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.292      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0215    |
# |    std                  | 0.766      |
# |    value_loss           | 1.84       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 32          |
# |    time_elapsed         | 680         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.036845572 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.758       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 33          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.036525287 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.232       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0087     |
# |    std                  | 0.754       |
# |    value_loss           | 0.827       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 34          |
# |    time_elapsed         | 722         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.037604786 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.472       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.748       |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 35          |
# |    time_elapsed         | 743         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.028836522 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.861       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00774    |
# |    std                  | 0.745       |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 36          |
# |    time_elapsed         | 764         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.053010218 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.754       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00323    |
# |    std                  | 0.742       |
# |    value_loss           | 3.67        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 37         |
# |    time_elapsed         | 787        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.03805036 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.31      |
# |    explained_variance   | 0.511      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.242      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 0.735      |
# |    value_loss           | 2.3        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 38          |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.039710913 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.825       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.000393    |
# |    std                  | 0.731       |
# |    value_loss           | 4.86        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 39          |
# |    time_elapsed         | 838         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.047674377 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.907       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00435    |
# |    std                  | 0.724       |
# |    value_loss           | 2.7         |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 94       |
# |    iterations           | 40       |
# |    time_elapsed         | 866      |
# |    total_timesteps      | 81920    |
# | train/                  |          |
# |    approx_kl            | 13.68019 |
# |    clip_fraction        | 0.624    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.24    |
# |    explained_variance   | 0.81     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.15     |
# |    n_updates            | 390      |
# |    policy_gradient_loss | 0.0301   |
# |    std                  | 0.722    |
# |    value_loss           | 9.07     |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 41          |
# |    time_elapsed         | 892         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.058228347 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.524       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0221      |
# |    std                  | 0.723       |
# |    value_loss           | 1.7         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 42          |
# |    time_elapsed         | 917         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.092986465 |
# |    clip_fraction        | 0.443       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.861       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00349    |
# |    std                  | 0.715       |
# |    value_loss           | 3.37        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 43         |
# |    time_elapsed         | 939        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.05261393 |
# |    clip_fraction        | 0.37       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0538     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00772   |
# |    std                  | 0.709      |
# |    value_loss           | 1.35       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 44          |
# |    time_elapsed         | 960         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.055745974 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.012       |
# |    std                  | 0.707       |
# |    value_loss           | 9.89        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 45          |
# |    time_elapsed         | 980         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.058217198 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.52        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0158      |
# |    std                  | 0.703       |
# |    value_loss           | 17.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 46          |
# |    time_elapsed         | 1001        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.051530153 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.407       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00993     |
# |    std                  | 0.7         |
# |    value_loss           | 2.62        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 47         |
# |    time_elapsed         | 1021       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.07510774 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.553      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.02       |
# |    std                  | 0.693      |
# |    value_loss           | 3.81       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 48          |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.040635068 |
# |    clip_fraction        | 0.434       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0303      |
# |    std                  | 0.693       |
# |    value_loss           | 12.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 49          |
# |    time_elapsed         | 1063        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.066807896 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.456       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0302      |
# |    std                  | 0.699       |
# |    value_loss           | 6.94        |
# -----------------------------------------

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_Model')
model.save(ppo_path)

# %%
del model

# %%
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
env = gym.make(environment_name, render_mode = 'human')
env = DummyVecEnv([lambda: env])

# %%
evaluate_policy(model, env, n_eval_episodes=10, render = True)
# Out:
# /Users/aidantyler/Reinforcement-Learning/.venv/lib/python3.13/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 evaluate_policy(model, env, n_eval_episodes=10, render = True)
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/stable_baselines3/common/evaluation.py:98, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      91 while (episode_counts < episode_count_targets).any():
#      92     actions, states = model.predict(
#      93         observations,  # type: ignore[arg-type]
#      94         state=states,
#      95         episode_start=episode_starts,
#      96         deterministic=deterministic,
#      97     )
# ---> 98     new_observations, rewards, dones, infos = env.step(actions)
#      99     current_rewards += rewards
#     100     current_lengths += 1
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/wrappers/common.py:124, in TimeLimit.step(self, action)
#     111 def step(
#     112     self, action: ActType
#     113 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     114     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     115
#     116     Args:
#    (...)    122
#     123     """
# --> 124     observation, reward, terminated, truncated, info = self.env.step(action)
#     125     self._elapsed_steps += 1
#     127     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/wrappers/common.py:392, in OrderEnforcing.step(self, action)
#     390 if not self._has_reset:
#     391     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 392 return super().step(action)
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/wrappers/common.py:284, in PassiveEnvChecker.step(self, action)
#     282     return env_step_passive_checker(self.env, action)
#     283 else:
# --> 284     return self.env.step(action)
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/envs/box2d/car_racing.py:585, in CarRacing.step(self, action)
#     582         step_reward = -100
#     584 if self.render_mode == "human":
# --> 585     self.render()
#     586 return self.state, step_reward, terminated, truncated, info
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/envs/box2d/car_racing.py:598, in CarRacing.render(self)
#     596     return
#     597 else:
# --> 598     return self._render(self.render_mode)
#
# File ~/Reinforcement-Learning/.venv/lib/python3.13/site-packages/gymnasium/envs/box2d/car_racing.py:648, in CarRacing._render(self, mode)
#     646 if mode == "human":
#     647     pygame.event.pump()
# --> 648     self.clock.tick(self.metadata["render_fps"])
#     649     assert self.screen is not None
#     650     self.screen.fill(0)
#
# KeyboardInterrupt:

# %%
env.close()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
